# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# forward bias
fb_table = pd.DataFrame({
    "Voltage (V)": [0.5, 0.7, 0.8, 0.9, 1.0, 1.1, 1.2, 1.4, 1.5, 1.6, 2.0],
    "Current (mA)": [0, 0.4, 0.6, 1.0, 1.4, 1.8, 2.2, 2.6, 3.4, 3.9, 4.2]
})

print(fb_table)
# Out:
#     Voltage (V)  Current (mA)
# 0           0.5           0.0
# 1           0.7           0.4
# 2           0.8           0.6
# 3           0.9           1.0
# 4           1.0           1.4
# 5           1.1           1.8
# 6           1.2           2.2
# 7           1.4           2.6
# 8           1.5           3.4
# 9           1.6           3.9
# 10          2.0           4.2

# %%
# reverse bias
rb_table = pd.DataFrame({
    "Voltage (V)": [0, 0.5, 1.0, 1.5, 2.0, 2.5, 3.0, 4.0, 5.0, 6.0],
    "Current (μA)": [0, 2, 2, 2, 2, 3, 4, 7, 11, 17]
})

print(rb_table)
# Out:
#    Voltage (V)  Current (μA)
# 0          0.0             0
# 1          0.5             2
# 2          1.0             2
# 3          1.5             2
# 4          2.0             2
# 5          2.5             3
# 6          3.0             4
# 7          4.0             7
# 8          5.0            11
# 9          6.0            17
